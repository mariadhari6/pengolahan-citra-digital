# %%
import cv2

# %%
gambar = cv2.imread("gambar.jpg", 1)

# %%
cv2.imshow("gambar", gambar)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x5575c64304c0) is not the object's thread (0x5575c6a76f30).
# Cannot move to target thread (0x5575c64304c0)
#
# QObject::moveToThread: Current thread (0x5575c64304c0) is not the object's thread (0x5575c6a76f30).
# Cannot move to target thread (0x5575c64304c0)
#
# QObject::moveToThread: Current thread (0x5575c64304c0) is not the object's thread (0x5575c6a76f30).
# Cannot move to target thread (0x5575c64304c0)
#
# QObject::moveToThread: Current thread (0x5575c64304c0) is not the object's thread (0x5575c6a76f30).
# Cannot move to target thread (0x5575c64304c0)
#
# QObject::moveToThread: Current thread (0x5575c64304c0) is not the object's thread (0x5575c6a76f30).
# Cannot move to target thread (0x5575c64304c0)
#
# QObject::moveToThread: Current thread (0x5575c64304c0) is not the object's thread (0x5575c6a76f30).
# Cannot move to target thread (0x5575c64304c0)
#
# ...
